# %%
import pandas as pd
from random import sample
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm

# %%
p2l_merged = pd.read_feather("../data/p2l_merged.feather")
l2p_merged = pd.read_feather("../data/l2p_merged.feather")
p2l_filtered = p2l_merged.drop(['fev1.fvc.ratio', 'gender', 'age','disease', 'smoking.status', 'race', 'percent.emphysema', 'pack.years'], axis=1)
l2p_filtered = l2p_merged.drop(['fev1.fvc.ratio', 'gender', 'age','disease', 'smoking.status', 'race', 'percent.emphysema', 'pack.years'], axis=1)

# %%
sm.qqplot(pd.Series(all_merged['beta_score_l2p']), line='s')
plt.title("QQ Plot All L2P Beta Score")

sm.qqplot(pd.Series(all_merged['beta_score_p2l']), line='s')
plt.title("QQ Plot All P2L Beta Score")

# %%
samples = sample(list(p2l_filtered['sample']), 1)


for i in samples:
    p2l_numeric_values = pd.to_numeric(p2l_filtered[p2l_filtered['sample'] == i].iloc[0], errors='coerce').dropna()
    l2p_numeric_values = pd.to_numeric(l2p_filtered[l2p_filtered['sample'] == i].iloc[0], errors='coerce').dropna()
    
    
    plt.figure()     
    plt.hist(p2l_numeric_values, bins=30)
    plt.xlabel("Edge Weight")
    plt.ylabel("Counts")
    plt.title("Edge Weights in P2L Sample " + i)
    plt.show()  
    
    plt.figure()
    sm.qqplot(pd.Series(p2l_numeric_values), line='s')
    plt.title(f"QQ Plot - P2L Sample {i}")
    plt.show()
    
    plt.figure()     
    plt.hist(l2p_numeric_values, bins=30)
    plt.xlabel("Edge Weight")
    plt.ylabel("Counts")
    plt.title("Edge Weights in L2P Sample " + i)
    plt.show()  
    
    plt.figure()
    sm.qqplot(pd.Series(l2p_numeric_values), line='s')
    plt.title(f"QQ Plot - L2P Sample {i}")
    plt.show()
    
    plt.figure()     
    filtered = [x for x in p2l_numeric_values if (x < 2) and (x > -2)]
    plt.hist(filtered, bins=30)
    plt.xlabel("Edge Weight")
    plt.ylabel("Counts")
    plt.title("Edge Weights in P2L Sample Filtered " + i)
    plt.show()  
    
    plt.figure()
    sm.qqplot(pd.Series(filtered), line='s')
    plt.title(f"QQ Plot - Filtered P2L Sample {i}")
    plt.show()
    
    plt.figure()     
    filtered = [x for x in l2p_numeric_values if (x < 2) and (x > -2)]
    plt.hist(filtered, bins=30)
    plt.xlabel("Edge Weight")
    plt.ylabel("Counts")
    plt.title("Edge Weights in L2P Sample Filtered " + i)
    plt.show()  
    
    plt.figure()
    sm.qqplot(pd.Series(filtered), line='s')
    plt.title(f"QQ Plot - Filtered L2P Sample {i}")
    plt.show()
    
    
    plt.figure()     
    filtered = [x for x in p2l_numeric_values if (x > 2)]
    plt.hist(filtered, bins=30)
    plt.xlabel("Edge Weight")
    plt.ylabel("Counts")
    plt.title("Edge Weights in P2L Sample Filtered " + i)
    plt.show()  
    
    plt.figure()
    sm.qqplot(pd.Series(filtered), line='s')
    plt.title(f"QQ Plot - Filtered P2L Sample {i}")
    plt.show()
    
    plt.figure()     
    filtered = [x for x in l2p_numeric_values if (x > 2)]
    plt.hist(filtered, bins=30)
    plt.xlabel("Edge Weight")
    plt.ylabel("Counts")
    plt.title("Edge Weights in L2P Sample Filtered " + i)
    plt.show()  
    
    plt.figure()
    sm.qqplot(pd.Series(filtered), line='s')
    plt.title(f"QQ Plot - Filtered P2L Sample {i}")
    plt.show()
