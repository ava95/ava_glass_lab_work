# %%
### CONFIRMED all_merged_new == all_merged_old

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from random import sample
from scipy.stats import pearsonr
from datetime import datetime

# %%
all_merged_new = pd.read_feather("../data/2025-12-04-23:17:02_regression_all_merged_gender_and_age.feather")
all_merged_old = pd.read_feather("../data/all_merged_full.feather")

# %%
all_merged_new[all_merged_new.index == "ZSCAN5C_MIR99B"]
# Out:
#                 beta_score_l2p  p_value_l2p  beta_score_p2l  p_value_p2l  \
# edge
# ZSCAN5C_MIR99B        0.078852     0.238208        0.021325     0.072284
#
#                 beta_score_diff  p_value_diff       TF    Gene  z_score_l2p  \
# edge
# ZSCAN5C_MIR99B         0.057527      0.165924  ZSCAN5C  MIR99B     0.750124
#
#                 z_score_p2l  z_score_diff  l2p_rank  p2l_rank  rank_diff  \
# edge
# ZSCAN5C_MIR99B     0.737409      0.012715  259169.0  264442.0    -5273.0
#
#                 abs_rank_diff
# edge
# ZSCAN5C_MIR99B         5273.0

# %%
all_merged_old[all_merged_old["edge"] == "ZSCAN5C_MIR99B"]
# Out:
#                   edge  beta_score_l2p  p_value_l2p  beta_score_p2l  \
# 325439  ZSCAN5C_MIR99B        0.078852     0.238208        0.021325
#
#         p_value_p2l  beta_score_diff  p_value_diff       TF    Gene  l2p_rank  \
# 325439     0.072284         0.057527      0.165924  ZSCAN5C  MIR99B  259169.0
#
#         p2l_rank  rank_diff  abs_rank_diff  z_score_l2p  z_score_p2l  \
# 325439  264442.0    -5273.0         5273.0     0.750124     0.737409
#
#         z_score_diff
# 325439      0.012715
